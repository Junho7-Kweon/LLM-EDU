# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI( api_key=api_key
)

print(client.api_key)
# Out:
# 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

# %%
fp = open('data/audio/베트남여행.mp3', 'rb')

transcription = client.audio.transcriptions.create(model="whisper-1", file=fp)
print(transcription.text)
print(transcription)

summary = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a summarize professional."},
        {"role": "user",   "content": transcription.text}
    ],
)
print(summary.choices[0].message.content)
# Out:
# 베트남 여행 준비물 30초로 정리하세요. 첫 번째, 100달러 지폐입니다. 달러 금액별로 다르게 환전해주는데 큰 금액의 달러를 더 잘 쳐줍니다. 두 번째, 트래블 월렉 카드. 트래블 월렉 카드를 이용하면 환전 수수료를 100% 우대해주고 베트남 BP뱅크 ATM을 이용하면 인출 수수료도 무료라는 사실! 바로 환전할 수 있어서 편합니다. 세 번째, 동지갑. 저는 만들기 귀찮아서 샀는데요. 워낙 지폐 종류가 많다 보니 이렇게 구분되어 있는 지갑을 가져가시는 걸 추천드립니다. 네 번째, 멀티템. 보조배터리, 미니선풍기, 휴대폰 등등등 충전할 전자기기가 너무 많죠? 멀티템 챙겨가시면 편합니다. 참고로 베트남은 대부분 220V 쓰니까 변화기는 필요 없습니다. 마지막으로 과도랑 포크. 망고 사드실 거면 챙겨가세요. 기내에는 못 들고 타는 거 아시죠? 꼭 위탁수화물에 붙이세요. 나머지는 댓글에 상세히 남겨두겠습니다. 구독하고 여행 꿀팁, 맛집 정보 받아보세요.
# Transcription(text='베트남 여행 준비물 30초로 정리하세요. 첫 번째, 100달러 지폐입니다. 달러 금액별로 다르게 환전해주는데 큰 금액의 달러를 더 잘 쳐줍니다. 두 번째, 트래블 월렉 카드. 트래블 월렉 카드를 이용하면 환전 수수료를 100% 우대해주고 베트남 BP뱅크 ATM을 이용하면 인출 수수료도 무료라는 사실! 바로 환전할 수 있어서 편합니다. 세 번째, 동지갑. 저는 만들기 귀찮아서 샀는데요. 워낙 지폐 종류가 많다 보니 이렇게 구분되어 있는 지갑을 가져가시는 걸 추천드립니다. 네 번째, 멀티템. 보조배터리, 미니선풍기, 휴대폰 등등등 충전할 전자기기가 너무 많죠? 멀티템 챙겨가시면 편합니다. 참고로 베트남은 대부분 220V 쓰니까 변화기는 필요 없습니다. 마지막으로 과도랑 포크. 망고 사드실 거면 챙겨가세요. 기내에는 못 들고 타는 거 아시죠? 꼭 위탁수화물에 붙이세요. 나머지는 댓글에 상세히 남겨두겠습니다. 구독하고 여행 꿀팁, 맛집 정보 받아보세요.', languages=None, logprobs=None, usage=UsageDuration(seconds=52.0, type='duration'))
# 베트남 여행 준비물 요약:
#
# 1. **100달러 지폐**: 큰 금액의 달러가 더 잘 환전됨.
# 2. **트래블 월렉 카드**: 환전 수수료 무료, BP뱅크 ATM에서 인출 수수료도 없음.
# 3. **동지갑**: 다양한 지폐를 구분하기에 유용.
# 4. **멀티템**: 보조배터리, 미니선풍기 등 여러 전자기기 충전을 위한 준비.
# 5. **과도 및 포크**: 망고 등 과일을 사려면 필수. 기내 반입 금지, 위탁 수화물에 넣어야 함.
#
# 자세한 정보는 댓글에 남길 예정이며, 구독하면 추가 여행 팁과 맛집 정보를 받을 수 있습니다!

# %%
import os
print(os.getcwd())  # 현재 작업 디렉토리 확인
print(os.path.exists('data/audio/베트남여행.mp3'))  # False면 경로가 틀린 것
# Out:
# c:\sk-encore\llm-workspace
# False

# %%
import os

print(os.listdir('.'))  # llm-workspace 바로 아래 뭐가 있는지

if os.path.exists('data'):
    print(os.listdir('data'))
else:
    print("data 폴더 자체가 없음")
# Out:
# ['.env', '.git', '.gitignore', '.python-version', '.venv', 'data', 'env (1).example', 'llm01_basic.ipynb', 'llm02_멀티모달_OPENAI.ipynb', 'main.py', 'pyproject.toml', 'README.md', 'uv.lock']
# ['베트남여행.mp3']

# %%
def transcribe_audio(file_path):
    fp = open(file_path, 'rb')
    transcription = client.audio.transcriptions.create(model="whisper-1", file=fp)

    fp.close()  # 파일 닫기
    return transcription.text

def transcribe_and_summarize(transcription_text):
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": "You are a summarize professional."},
                {"role": "user",   "content": transcription_text}
            ],
        )
        return response.choices[0].message.content

transcription_text = transcribe_audio('data/audio/베트남여행.mp3')
print("Transcription:", transcription_text)
# Out:
# Transcription: 베트남 여행 준비물 30초로 정리하세요. 첫 번째, 100달러 지폐입니다. 달러 금액별로 다르게 환전해주는데 큰 금액의 달러를 더 잘 쳐줍니다. 두 번째, 트래블 월레카드. 트래블 월레카드를 이용하면 환전 수수료를 100% 우대해주고 베트남 BP뱅크 ATM을 이용하면 인출 수수료도 무료라는 사실! 바로 환전할 수 있어서 편합니다. 세 번째, 동지갑. 저는 만들기 귀찮아서 샀는데요. 워낙 지폐 종류가 많다 보니 이렇게 구분되어 있는 지갑을 가져가시는 걸 추천드립니다. 네 번째, 멀티템. 보조배터리, 미니 선풍기, 휴대폰 등등등 충전할 전자기기가 너무 많죠? 멀티템 챙겨가시면 편합니다. 참고로 베트남은 대부분 220V 쓰니까 변화기는 필요 없습니다. 마지막으로 과도랑 포크. 망고 사드실 거면 챙겨가세요. 기내에는 못 들고 타는 거 아시죠? 꼭 위탁수화물에 붙이세요. 나머지는 댓글에 상세히 남겨두겠습니다. 구독하고 여행 꿀팁, 맛집 정보 받아보세요.

# %% [markdown]
# voice 옵션 https://platform.openai.com/docs/models/tts-1

# %%
import os

response = client.audio.speech.create(
    input='안녕하세요 오늘 날씨가 참 덥네요',
    model="tts-1",
    voice="alloy"
)

os.makedirs('output', exist_ok=True)  # 폴더 없으면 생성

with open('output/out.mp3', 'wb') as f:
    f.write(response.read())

# %%
from openai import OpenAI
from playsound import playsound
from IPython.display import Audio

prompt = input('prompt: ')

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": prompt}
    ],
)
resp = response.choices[0].message.content
print('gpt', resp)
# Out:
# gpt 안녕하세요! 어떻게 도와드릴까요?

# %% [markdown]
# 3. dall-e-3 이미지생성

# %%
# Out:
#   Cell In[18], line 1
#     3. dall-e-3 이미지생성
#        ^
# SyntaxError: invalid syntax

# %%
from openai import OpenAI
import requests

#dall-e-2 편집모델, dall-e-3 편집모델, gpt-image-1 편집모델

#이미지 모델 생성
response = client.images.generate(
    prompt="Messi and Ronaldo playing soccer together in a futuristic stadium, ultra-realistic, cinematic lighting, 8k resolution",
    size="1024x1024",
    model="gpt-image-1",
    quality="high",
    n=1
)

image_url = response.data[0].url
print("Image URL:", image_url)

#이미지 다운로드 및 저장 (DALL-E 3 기본포멧인 png 확장자 권장)
image_data = requests.get(image_url).content   
with open('output/generated_image.png', 'wb') as f:
    f.write(image_data)

print("Image saved as 'output/generated_image.png'" )
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[22], line 7
#       3
#       4 #dall-e-2 편집모델, dall-e-3 편집모델, gpt-image-1 편집모델
#       5
#       6 #이미지 모델 생성
# ----> 7 response = client.images.generate(
#       8     prompt="Messi and Ronaldo playing soccer together in a futuristic stadium, ultra-realistic, cinematic lighting, 8k resolution",
#       9     size="1024x1024",
#      10     model="gpt-image-1",
#
# File c:\sk-encore\llm-workspace\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\sk-encore\llm-workspace\.venv\Lib\site-packages\openai\resources\images.py:1012, in Images.generate(self, prompt, background, model, moderation, n, output_compression, output_format, partial_images, quality, response_format, size, stream, style, user, extra_headers, extra_query, extra_body, timeout)
#     982 @required_args(["prompt"], ["prompt", "stream"])
#     983 def generate(
#     984     self,
#    (...)   1010     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1011 ) -> ImagesResponse | Stream[ImageGenStreamEvent]:
# -> 1012     return self._post(
#    1013         "/images/generations",
#    1014         body=maybe_transform(
#    1015             {
#    1016                 "prompt": prompt,
#    1017                 "background": background,
#    1018                 "model": model,
#    1019                 "moderation": moderation,
#    1020                 "n": n,
#    1021                 "output_compression": output_compression,
#    1022                 "output_format": output_format,
#    1023                 "partial_images": partial_images,
#    1024                 "quality": quality,
#    1025                 "response_format": response_format,
#    1026                 "size": size,
#    1027                 "stream": stream,
#    1028                 "style": style,
#    1029                 "user": user,
#    1030             },
#    1031             image_generate_params.ImageGenerateParamsStreaming
#    1032             if stream
#    1033             else image_generate_params.ImageGenerateParamsNonStreaming,
#    1034         ),
#    1035         options=make_request_options(
#    1036             extra_headers=extra_headers,
#    1037             extra_query=extra_query,
#    1038             extra_body=extra_body,
#    1039             timeout=timeout,
#    1040             security={"bearer_auth": True},
#    1041         ),
#    1042         cast_to=ImagesResponse,
#    1043         stream=stream or False,
#    1044         stream_cls=Stream[ImageGenStreamEvent],
#    1045     )
#
# File c:\sk-encore\llm-workspace\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\sk-encore\llm-workspace\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1138             err.response.read()
#    1140         log.debug("Re-raising status error")
# -> 1141         raise self._make_status_error_from_response(err.response) from None
#    1143     break
#    1145 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Your request was rejected by the safety system. If you believe this is an error, contact us at help.openai.com and include the request ID req_b340cfbcbe314c7cbd0a65ef67bc36c3.', 'type': 'image_generation_user_error', 'param': None, 'code': 'moderation_blocked', 'moderation_details': {'moderation_stage': 'input', 'categories': ['public-figure']}}}

# %%
from openai import OpenAI
import base64
import os

# dall-e-2 편집모델, dall-e-3 편집모델, gpt-image-1 편집모델

# 이미지 모델 생성
response = client.images.generate(
    prompt="Two professional soccer players in different colored jerseys playing together in a futuristic stadium, ultra-realistic, cinematic lighting, 8k resolution",
    size="1024x1024",
    model="gpt-image-1",
    quality="high",
    n=1
)

# gpt-image-1은 URL이 아니라 base64로 인코딩된 이미지를 반환함
image_base64 = response.data[0].b64_json
image_bytes = base64.b64decode(image_base64)

# 저장 폴더 없으면 생성
os.makedirs('output', exist_ok=True)

with open('output/generated_image.png', 'wb') as f:
    f.write(image_bytes)

print("Image saved as 'output/generated_image.png'")
# Out:
# Image saved as 'output/generated_image.png'

# %%
from openai import OpenAI
import base64

def encode_image(image_path):
    with open(image_path, 'rb') as f:
        image_bytes = f.read()
    return base64.b64encode(image_bytes).decode('utf-8')

image_path = 'image/명함.png'  # 실제 이미지 경로로 변경
encoded_image = encode_image(image_path)

data_url = f"data:image/png;base64,{encoded_image}"

# %%
print(img_response.status_code)
print(img_response.headers.get('Content-Type'))
print(img_response.content[:100])  # 이미지 바이너리면 \x89PNG나 \xff\xd8\xff(JPEG 시그니처)로 시작함
# Out:
# 404
# text/html; charset=UTF-8
# b'File not found: /v1/AUTH_mw/wikipedia-commons-local-public.4f/4/4f/Iconic_image_of_Messi_and_Ronaldo'

# %%
def encode_image(image_path):
    with open(image_path, 'rb') as f:
        image_bytes = f.read()
    return base64.b64encode(image_bytes).decode('utf-8')

base64_image = encode_image('image/Lionel_Messi_PSG.jpg')
data_url = f"data:image/jpeg;base64,{base64_image}"

prompt = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지를 분석하고 설명해 주세요."},
            {"type": "image_url", "image_url": {"url": data_url}}
        ]
    }
]

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=prompt,
    temperature=0.7,
    max_tokens=512
)

print(response.choices[0].message.content)
# Out:
# 이 이미지는 축구 선수가 경기 중인 모습으로 보입니다. 선수는 파리 생제르맹(PSG)의 유니폼을 입고 있으며, 등번호는 30입니다. 유니폼은 어두운 파란색으로 디자인되어 있고, 흰색과 빨간색의 스트라이프가 있습니다. 선수는 다소 집중한 표정을 짓고 있으며, 손으로 팔을 감싸고 있는 모습입니다. 배경은 축구 경기장으로 보이며, 잔디 상태가 양호해 보입니다. 이 이미지는 축구 경기의 긴장감과 선수의 집중력을 잘 나타내고 있습니다.

# %% [markdown]
# ## 1. 위도와 경도를 통해 날씨 정보를 얻는 함수
# - 기상청 데이터 및 API(예: Open-Meteo, ECMWF, ERA5 등)
# - 표준 관측 높이: 세계기상기구(WMO) 표준에 따라 지열의 직접적인 영향 및 미세한 지표면 변동을 줄이고 사람의 체감에 가까운 기온을 측정하기 위해 2미터 높이를 기준으로 합니다.
#
# - 단위: API 및 데이터셋에 따라 일반적으로 섭씨(°C) 또는 켈빈(K)을 사용합니다.

# %%
import requests

# 위도 latitude, 경도 longitude
def get_weather(latitude, longitude):
    response = requests.get(f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m,wind_speed_10m&hourly=temperature_2m,relative_humidity_2m,wind_speed_10m")
    #print(response)
    #print(dir(response))
    data = response.json()
    print(data)
    print('data:',data['current'] )
    return data['current']['temperature_2m']  # 기온 (temperature_2m): 21.1°C
    # return data['current']['temperature_2m'], data['current']['time']

# %%
import openmeteo_requests
import requests_cache
from retry_requests import retry

import openmeteo_requests
import requests_cache
from retry_requests import retry

# 1. OpenAI 클라이언트 생성
# client = OpenAI()

# 2. 날씨 정보 조회 함수 정의 (Open-Meteo API 사용)
# 위도 latitude, 경도 longitude
def get_weather(latitude, longitude):

    # Open-Meteo API 전용 SDK 라이브러리와 캐싱 및 재시도 기능을 위한 세션 객체를 설정합니다.
    # 캐시 세션: 동일한 API 요청이 반복될 경우 서버 요청 없이 '.cache' 파일에 저장된 데이터를 사용합니다 (유효기간: 1시간).
    cache_session = requests_cache.CachedSession('.cache', expire_after=3600)

    # 재시도 세션: 네트워크 에러나 서버 오류 발생 시 최대 5회까지 자동 재시도하며, 시도 간격을 지수적으로 늘립니다 (backoff_factor: 0.2초).
    retry_session = retry(cache_session, retries=5, backoff_factor=0.2)

    # 설정한 캐시 및 재시도 정책이 적용된 Open-Meteo 전용 클라이언트 객체를 생성합니다.
    openmeteo = openmeteo_requests.Client(session=retry_session)

    # 데이터를 요청할 Open-Meteo 기상 예보 API의 엔드포인트 URL을 지정합니다.
    url = "https://api.open-meteo.com/v1/forecast"

    # API 요청 시 전달할 쿼리 파라미터를 딕셔너리 형태로 구성합니다.
    params = {
        # 조회할 위치의 위도(서울 좌표: 37.5665)를 지정합니다.
        "latitude": latitude,
        # 조회할 위치의 경도(서울 좌표: 126.9780)를 지정합니다.
        "longitude": longitude,
        # 실시간으로 가져올 기상 항목 목록을 설정합니다 (2m 높이 기온, 2m 높이 상대습도).
        "current": ["temperature_2m", "relative_humidity_2m"],
        # 시간대 기준을 한국 표준시(KST)로 설정합니다.
        "timezone": "Asia/Seoul"
    }
    
    response = openmeteo.weather_api(url, params=params)[0]   

    # 응답 객체에서 현재 기상 정보 데이터(Current) 블록을 추출합니다.
    current = response.Current()

    # 현재 기온 (temperature_2m: 인덱스 0) 추출하여 반환
    temp = current.Variables(0).Value()
    return temp

# %%
get_weather(37.5665, 126.9780)  # 서울 좌표
# Out:
# 21.936498641967773

# %%
import requests

# 위도 latitude, 경도 longitude
def get_weather(latitude, longitude):
    response = requests.get(f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m,wind_speed_10m&hourly=temperature_2m,relative_humidity_2m,wind_speed_10m")
    #print(response)
    #print(dir(response))
    data = response.json()
    print(data)
    print('data:',data['current'] )
    return data['current']['temperature_2m']  # 기온 (temperature_2m): 21.1°C
    # return data['current']['temperature_2m'], data['current']['time']

# %%
# GPT에 전달할 Tool(함수) 스키마 정의
# get_weather(위도, 경도)

temp = get_weather(37.5642135, 127.0016985)

# 추출한 기온 값을 소수점 이하 첫째 자리까지 서식화하여 출력합니다.
print(f'서울 현재 기온: {temp:.1f}°C"')
# Out:
# {'latitude': 37.55, 'longitude': 127.0, 'generationtime_ms': 0.23174285888671875, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 32.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C', 'wind_speed_10m': 'km/h'}, 'current': {'time': '2026-09-10T06:30', 'interval': 900, 'temperature_2m': 22.2, 'wind_speed_10m': 3.6}, 'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C', 'relative_humidity_2m': '%', 'wind_speed_10m': 'km/h'}, 'hourly': {'time': ['2026-09-10T00:00', '2026-09-10T01:00', '2026-09-10T02:00', '2026-09-10T03:00', '2026-09-10T04:00', '2026-09-10T05:00', '2026-09-10T06:00', '2026-09-10T07:00', '2026-09-10T08:00', '2026-09-10T09:00', '2026-09-10T10:00', '2026-09-10T11:00', '2026-09-10T12:00', '2026-09-10T13:00', '2026-09-10T14:00', '2026-09-10T15:00', '2026-09-10T16:00', '2026-09-10T17:00', '2026-09-10T18:00', '2026-09-10T19:00', '2026-09-10T20:00', '2026-09-10T21:00', '2026-09-10T22:00', '2026-09-10T23:00', '2026-09-11T00:00', '2026-09-11T01:00', '2026-09-11T02:00', '2026-09-11T03:00', '2026-09-11T04:00', '2026-09-11T05:00', '2026-09-11T06:00', '2026-09-11T07:00', '2026-09-11T08:00', '2026-09-11T09:00', '2026-09-11T10:00', '2026-09-11T11:00', '2026-09-11T12:00', '2026-09-11T13:00', '2026-09-11T14:00', '2026-09-11T15:00', '2026-09-11T16:00', '2026-09-11T17:00', '2026-09-11T18:00', '2026-09-11T19:00', '2026-09-11T20:00', '2026-09-11T21:00', '2026-09-11T22:00', '2026-09-11T23:00', '2026-09-12T00:00', '2026-09-12T01:00', '2026-09-12T02:00', '2026-09-12T03:00', '2026-09-12T04:00', '2026-09-12T05:00', '2026-09-12T06:00', '2026-09-12T07:00', '2026-09-12T08:00', '2026-09-12T09:00', '2026-09-12T10:00', '2026-09-12T11:00', '2026-09-12T12:00', '2026-09-12T13:00', '2026-09-12T14:00', '2026-09-12T15:00', '2026-09-12T16:00', '2026-09-12T17:00', '2026-09-12T18:00', '2026-09-12T19:00', '2026-09-12T20:00', '2026-09-12T21:00', '2026-09-12T22:00', '2026-09-12T23:00', '2026-09-13T00:00', '2026-09-13T01:00', '2026-09-13T02:00', '2026-09-13T03:00', '2026-09-13T04:00', '2026-09-13T05:00', '2026-09-13T06:00', '2026-09-13T07:00', '2026-09-13T08:00', '2026-09-13T09:00', '2026-09-13T10:00', '2026-09-13T11:00', '2026-09-13T12:00', '2026-09-13T13:00', '2026-09-13T14:00', '2026-09-13T15:00', '2026-09-13T16:00', '2026-09-13T17:00', '2026-09-13T18:00', '2026-09-13T19:00', '2026-09-13T20:00', '2026-09-13T21:00', '2026-09-13T22:00', '2026-09-13T23:00', '2026-09-14T00:00', '2026-09-14T01:00', '2026-09-14T02:00', '2026-09-14T03:00', '2026-09-14T04:00', '2026-09-14T05:00', '2026-09-14T06:00', '2026-09-14T07:00', '2026-09-14T08:00', '2026-09-14T09:00', '2026-09-14T10:00', '2026-09-14T11:00', '2026-09-14T12:00', '2026-09-14T13:00', '2026-09-14T14:00', '2026-09-14T15:00', '2026-09-14T16:00', '2026-09-14T17:00', '2026-09-14T18:00', '2026-09-14T19:00', '2026-09-14T20:00', '2026-09-14T21:00', '2026-09-14T22:00', '2026-09-14T23:00', '2026-09-15T00:00', '2026-09-15T01:00', '2026-09-15T02:00', '2026-09-15T03:00', '2026-09-15T04:00', '2026-09-15T05:00', '2026-09-15T06:00', '2026-09-15T07:00', '2026-09-15T08:00', '2026-09-15T09:00', '2026-09-15T10:00', '2026-09-15T11:00', '2026-09-15T12:00', '2026-09-15T13:00', '2026-09-15T14:00', '2026-09-15T15:00', '2026-09-15T16:00', '2026-09-15T17:00', '2026-09-15T18:00', '2026-09-15T19:00', '2026-09-15T20:00', '2026-09-15T21:00', '2026-09-15T22:00', '2026-09-15T23:00', '2026-09-16T00:00', '2026-09-16T01:00', '2026-09-16T02:00', '2026-09-16T03:00', '2026-09-16T04:00', '2026-09-16T05:00', '2026-09-16T06:00', '2026-09-16T07:00', '2026-09-16T08:00', '2026-09-16T09:00', '2026-09-16T10:00', '2026-09-16T11:00', '2026-09-16T12:00', '2026-09-16T13:00', '2026-09-16T14:00', '2026-09-16T15:00', '2026-09-16T16:00', '2026-09-16T17:00', '2026-09-16T18:00', '2026-09-16T19:00', '2026-09-16T20:00', '2026-09-16T21:00', '2026-09-16T22:00', '2026-09-16T23:00'], 'temperature_2m': [17.2, 18.5, 19.6, 21.2, 21.5, 22.0, 22.2, 22.2, 22.3, 21.9, 20.4, 19.6, 19.0, 18.3, 17.9, 1 ...
# data: {'time': '2026-09-10T06:30', 'interval': 900, 'temperature_2m': 22.2, 'wind_speed_10m': 3.6}
# 서울 현재 기온: 22.2°C"

# %%
import openmeteo_requests
import requests_cache
from retry_requests import retry

import openmeteo_requests
import requests_cache
from retry_requests import retry

# 1. OpenAI 클라이언트 생성
# client = OpenAI()

# 2. 날씨 정보 조회 함수 정의 (Open-Meteo API 사용)
# 위도 latitude, 경도 longitude
def get_weather(latitude, longitude):

    # Open-Meteo API 전용 SDK 라이브러리와 캐싱 및 재시도 기능을 위한 세션 객체를 설정합니다.
    # 캐시 세션: 동일한 API 요청이 반복될 경우 서버 요청 없이 '.cache' 파일에 저장된 데이터를 사용합니다 (유효기간: 1시간).
    cache_session = requests_cache.CachedSession('.cache', expire_after=3600)

    # 재시도 세션: 네트워크 에러나 서버 오류 발생 시 최대 5회까지 자동 재시도하며, 시도 간격을 지수적으로 늘립니다 (backoff_factor: 0.2초).
    retry_session = retry(cache_session, retries=5, backoff_factor=0.2)

    # 설정한 캐시 및 재시도 정책이 적용된 Open-Meteo 전용 클라이언트 객체를 생성합니다.
    openmeteo = openmeteo_requests.Client(session=retry_session)

    # 데이터를 요청할 Open-Meteo 기상 예보 API의 엔드포인트 URL을 지정합니다.
    url = "https://api.open-meteo.com/v1/forecast"

    # API 요청 시 전달할 쿼리 파라미터를 딕셔너리 형태로 구성합니다.
    params = {
        # 조회할 위치의 위도(서울 좌표: 37.5665)를 지정합니다.
        "latitude": latitude,
        # 조회할 위치의 경도(서울 좌표: 126.9780)를 지정합니다.
        "longitude": longitude,
        # 실시간으로 가져올 기상 항목 목록을 설정합니다 (2m 높이 기온, 2m 높이 상대습도).
        "current": ["temperature_2m", "relative_humidity_2m"],
        # 시간대 기준을 한국 표준시(KST)로 설정합니다.
        "timezone": "Asia/Seoul"
    }
    
    response = openmeteo.weather_api(url, params=params)[0]   

    # 응답 객체에서 현재 기상 정보 데이터(Current) 블록을 추출합니다.
    current = response.Current()

    # 현재 기온 (temperature_2m: 인덱스 0) 추출하여 반환
    temp = current.Variables(0).Value()
    return temp

# %%
# 3. GPT에 전달할 Tool(함수) 스키마 정의

# OpenAI API 모델에 전달할 Tool(함수 호출) 정의 리스트입니다.
wtool = [
    {
        # 이 도구가 실행 가능한 함수(function) 형태임을 명시합니다.
        "type": "function",
        "function": {
            # GPT가 호출할 파이썬 함수 이름을 지정합니다.
            "name": "get_weather",
            # 모델이 어떤 상황에 이 함수를 호출할지 판단하는 설명(프롬프트)입니다.
            "description": "Get current temperature for provided coordinates in celsius.",
            # 함수 실행 시 전달할 매개변수(인자)의 구조를 JSON Schema 형태로 정의합니다.
            "parameters": {
                # 매개변수 집합의 기본 데이터 타입을 객체(Object/Dict)로 지정합니다.
                "type": "object",
                # 함수에 전달될 각 인자의 속성을 정의합니다.
                "properties": {
                    # 위도 값 속성이며, 데이터 타입은 숫자(number)입니다.
                    "latitude": {"type": "number"},
                    # 경도 값 속성이며, 데이터 타입은 숫자(number)입니다.
                    "longitude": {"type": "number"},
                },
                # 함수 호출 시 반드시 전달되어야 하는 필수 인자 목록입니다.
                "required": ["latitude", "longitude"],
                # 스키마에 정의되지 않은 추가 인자의 생성을 금지합니다 (Strict Mode 필수 조건).
                "additionalProperties": False,
            },
            # 정의한 스키마 구조를 100% 엄격하게 준수하여 인자를 생성하도록 설정합니다.
            "strict": True,
        },
    }
]

# %%
import json

# 4. GPT API 호출 (Function Calling 유도)
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "현재 제주도 날씨는?"}],
    tools=wtool,
)

# 5. Tool Call 결과 확인 및 Arguments 파싱
tool_call = response.choices[0].message.tool_calls[0]
raw_args = tool_call.function.arguments

print("GPT가 반환한 arguments (str):", raw_args)
print("타입:", type(raw_args))

# JSON 문자열 -> Python dict 변환
args = json.loads(raw_args)
print("파싱된 args (dict):", args)
print("타입:", type(args))

# 6. 추출된 위도/경도로 실제 날씨 함수 실행
c = get_weather(args["latitude"], args["longitude"])
print(f"현재 제주도 기온: {c:.1f}°C")
# Out:
# GPT가 반환한 arguments (str): {"latitude":33.4996,"longitude":126.5312}
# 타입: <class 'str'>
# 파싱된 args (dict): {'latitude': 33.4996, 'longitude': 126.5312}
# 타입: <class 'dict'>
# 현재 제주도 기온: 24.7°C
