# %% [markdown]
# ✅ PromptTemplate (from langchain.prompts)
# - 텍스트 기반 LLM (예: GPT-3.5, GPT-4 텍스트모드)용
# - 하나의 문자열을 생성
# - 단순하고 직관적인 형식
#
# ✅ ChatPromptTemplate (from langchain_core.prompts)
# - 챗 기반 LLM (예: ChatGPT, GPT-4o)용
# - 역할(role: system/user/assistant 등)을 기반으로 구성된 메시지 리스트 사용
# - 대화형 프롬프트를 정의할 수 있음

# %%
#uv add langchain langchain_openai

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts  import PromptTemplate

# %%
product = "컴퓨터"
s = f"{product} 제품 홍보문구 작성해줘"
s
# Out:
# '컴퓨터 제품 홍보문구 작성해줘'

# %% [markdown]
# ### PromptTemplate

# %%
template ="{product} 제품 홍보문구 작성해줘"
prompt = PromptTemplate(input_variables=['product'], template=template )
txt = prompt.format(product="컴퓨터")
txt
# Out:
# '컴퓨터 제품 홍보문구 작성해줘'

# %%
template ="{product} 제품 홍보문구 {desc}"
prompt = PromptTemplate( input_variables=['product', 'desc'], template=template )
txt = prompt.format( product="컴퓨터", desc="설명해줘" )
txt
# Out:
# '컴퓨터 제품 홍보문구 설명해줘'

# %%
template ="오늘은 {day}입니다. {name}님, 좋은 하루 되세요."
prompt = PromptTemplate( input_variables=['name'],
                        partial_variables={'day': '화요일'},
                        template=template )
txt = prompt.format(name="홍길동")
txt
# Out:
# '오늘은 화요일입니다. 홍길동님, 좋은 하루 되세요.'

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain_openai import ChatOpenAI

template ="{product} 제품 홍보문구 작성해줘"
prompt = PromptTemplate( input_variables=['product'], template=template )

gpt =  ChatOpenAI( model="gpt-4o-mini", temperature=0)
rst =gpt.invoke( prompt.format(product="컴퓨터") )
# rst =gpt.invoke( "컴퓨터 제품 홍보문구 작성해줘" )
# rst =gpt.invoke( [HumanMessage(content= prompt.format(product="컴퓨터") ) ] )
print( rst.content)
# Out:
# 물론입니다! 아래는 컴퓨터 제품을 홍보하기 위한 몇 가지 문구 예시입니다.
#
# 1. **"최신 기술, 무한한 가능성! 당신의 작업을 혁신할 컴퓨터를 만나보세요!"**
#
# 2. **"강력한 성능, 세련된 디자인! 모든 작업을 완벽하게 소화하는 당신의 새로운 파트너!"**
#
# 3. **"게임, 작업, 창작 – 모든 것을 한 번에! 최고의 성능을 경험하세요!"**
#
# 4. **"속도와 안정성의 완벽한 조화! 당신의 생산성을 극대화할 컴퓨터!"**
#
# 5. **"미래를 준비하세요! 최신 사양으로 무장한 컴퓨터로 한 단계 더 나아가세요!"**
#
# 6. **"어디서나, 언제나! 휴대성과 성능을 겸비한 컴퓨터로 자유롭게 작업하세요!"**
#
# 7. **"당신의 아이디어를 현실로! 창의력을 자극하는 최적의 컴퓨터!"**
#
# 이 문구들을 참고하여 제품의 특징이나 타겟 고객에 맞게 조정하시면 좋습니다!

# %% [markdown]
# ## ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "{product} 제품 홍보문구 작성해줘")
])
prompt.format_messages(product="컴퓨터")
# Out:
# [SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='컴퓨터 제품 홍보문구 작성해줘', additional_kwargs={}, response_metadata={})]

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "{product} 제품 홍보문구 작성해줘")
])
gpt = ChatOpenAI( model="gpt-4o-mini", temperature=0)
rst = gpt.invoke( prompt.format_messages(product="컴퓨터") )
print( rst.content)
# Out:
# 물론입니다! 아래는 컴퓨터 제품을 홍보하기 위한 몇 가지 문구입니다. 필요에 따라 수정하거나 조합하여 사용하실 수 있습니다.
#
# 1. **"최신 기술로 무장한 당신의 컴퓨터, 이제 더 빠르고 강력하게!"**
#
# 2. **"생산성을 높여주는 스마트한 선택, 우리의 컴퓨터와 함께하세요!"**
#
# 3. **"게임, 작업, 창작 – 모든 것을 완벽하게 소화하는 컴퓨터!"**
#
# 4. **"탁월한 성능과 세련된 디자인, 당신의 스타일을 완성합니다!"**
#
# 5. **"한 번의 클릭으로 경험하는 초고속 처리, 새로운 차원의 컴퓨팅!"**
#
# 6. **"모든 작업을 손쉽게! 당신의 일상을 혁신하는 컴퓨터!"**
#
# 7. **"강력한 성능, 뛰어난 안정성 – 믿을 수 있는 파트너!"**
#
# 8. **"당신의 아이디어를 현실로! 창의력을 자극하는 컴퓨터!"**
#
# 9. **"최고의 성능을 경험하세요! 게임과 작업 모두를 완벽하게!"**
#
# 10. **"지금 바로 업그레이드하세요! 미래의 컴퓨팅을 경험할 시간입니다!"**
#
# 이 문구들이 도움이 되길 바랍니다! 추가적인 요청이 있으시면 말씀해 주세요.

# %%
# client = OpenAI()

# completion = client.chat.completions.create(model="gpt-4o-mini",
#     messages=[
#         {'role':'system', 'content':'You are a helpful teacher'},
#         {'role':'user',
#             'content':'Are ther other measure than time complexity for an algorithm?'},
#         {'role':'assistant',
#             'content':'Yes, there are other measures besides time complexity\
#             for an algorithm, such as space complexity.' },
#         {'role':'user','content':'What is it?'}] )

# print( completion.choices[0].message.content)

## 2분 퀴즈 ChatPromptTemplate 으로 위와 같은 결과를 출력해보세요.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(model="gpt-4o-mini")

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful teacher"),
    ("human", "What algorithms are commonly used in sports, like ranking players or teams?"),
    ("ai", "Yes, sports commonly use algorithms such as the ELO rating system for ranking players, "
           "and various tournament bracket algorithms for scheduling matches."),
    ("human", "Can you explain how the ELO rating system works?")
])

chain = prompt | llm

response = chain.invoke({})
print(response.content)
# Out:
# Certainly! The ELO rating system is a method for calculating the relative skill levels of players in two-player games, though it is widely adapted for team sports as well. Here’s how it works:
#
# ### Basic Concepts:
# 1. **Initial Rating**: Each player starts with a standard rating, often set to 1500.
# 2. **Expected Score**: Before a match, the expected score for each player is calculated based on their current ratings.
#
# ### Formula:
# The expected score for Player A against Player B is calculated using the following formula:
#
# \[
# E_A = \frac{1}{1 + 10^{(R_B - R_A)/400}}
# \]
#
# Where:
# - \(E_A\) is the expected score for Player A.
# - \(R_A\) is Player A's current rating.
# - \(R_B\) is Player B's current rating.
#
# ### Match Outcome:
# 1. **Actual Score**: After the match, the actual score is recorded:
#    - Win: Score = 1
#    - Draw: Score = 0.5
#    - Loss: Score = 0
#
# ### Rating Update:
# The rating for each player is updated based on the actual outcome of the match versus the expected outcome. The formula for updating the rating is:
#
# \[
# R'_A = R_A + K \times (S_A - E_A)
# \]
#
# Where:
# - \(R'_A\) is the new rating for Player A.
# - \(K\) is a constant (K-factor), which determines the maximum possible adjustment per game. It can vary depending on the level of play; it’s generally higher for less experienced players and lower for seasoned players.
# - \(S_A\) is the actual score achieved by Player A in the match.
#
# ### Example:
# - If Player A (rating 1600) plays Player B (rating 1400):
#   - Calculate expected scores for both players.
#   - If Player A wins, their rating will increase and Player B’s will decrease.
#
# ### Key Features:
# - **Dynamic**: Ratings change after each game based on performance against varying opponents.
# - **Head-to-Head**: Reflects players' relative performance directly against each other.
# - **Adaptable**: Used in various sports and games, not limited to chess where it originated.
#
# ### Strengths and Limitations:
# - **Advantages**: Provides a continual update based on performance, accounts for the strength of the opponent.
# - **Limitations**: It can be sensitive to outliers (e.g., unexpected losses) and requires a sufficient number of games to stabilize the ratings meaningfully.
#
# Overall, the ELO system is an effective way to rank players or teams based on their performance and is widely utilized in chess, esports, and various team sports.

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful teacher"),
    ("human", "Are ther other measure than time complexity for an {algorithm}?"),
    ("ai", "Yes, there are other measures besides time complexity for an {algorithm}, such as space complexity."),
    ("human", "What is it?"),
])
gpt = ChatOpenAI(model="gpt-4o-mini" , temperature=0)
rst = gpt.invoke( prompt.format_messages(algorithm="algorithm") )
print(rst.content)
# Out:
# Space complexity is a measure of the amount of working storage an algorithm requires as a function of the size of the input to the program. It quantifies the total space needed for the algorithm to execute, including:
#
# 1. **Fixed Part**: This includes space required for constants, simple variables, fixed-size variables, and program code. This part is independent of the size of the input.
#
# 2. **Variable Part**: This includes space required for dynamically allocated memory, recursion stack space, and space required for data structures (like arrays, linked lists, trees, etc.) that depend on the size of the input.
#
# Space complexity is often expressed in Big O notation, similar to time complexity, to describe how the space requirements grow with the input size. For example:
# - An algorithm with a space complexity of \(O(1)\) uses a constant amount of space regardless of input size.
# - An algorithm with a space complexity of \(O(n)\) uses space that grows linearly with the input size.
#
# Understanding both time and space complexity is crucial for evaluating the efficiency of an algorithm, especially in environments with limited resources.

# %%
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="Are ther other measure than time complexity for an algorithm?"),
    AIMessage(content="Yes, there are other measures besides time complexity for an algorithm, such as space complexity."),
    HumanMessage(content="What is it?")]

gpt = ChatOpenAI( model="gpt-4o-mini", temperature=0)
rst = gpt.invoke( messages )
print( rst.content )
# Out:
# Space complexity is a measure of the amount of working storage an algorithm requires as a function of the size of the input to the program. It quantifies the total space needed by the algorithm, including both the space for the input values and the space required for the algorithm's variables, data structures, and any additional memory used during execution.
#
# Space complexity is typically expressed in terms of Big O notation, similar to time complexity. It can be broken down into two main components:
#
# 1. **Fixed Part**: This includes the space required for constants, simple variables, fixed-size variable components, and program code. This part does not depend on the size of the input.
#
# 2. **Variable Part**: This includes the space required for dynamically allocated memory, variable-sized data structures (like arrays, lists, trees, etc.), and recursion stack space. This part depends on the size of the input.
#
# The overall space complexity is the sum of the fixed and variable parts, and it helps in understanding how the algorithm scales with larger inputs in terms of memory usage.
#
# ### Example
# For instance, consider a simple algorithm that uses an array of size \( n \) to store input data. The space complexity of this algorithm would be \( O(n) \) because the space required grows linearly with the size of the input.
#
# ### Other Measures
# In addition to time and space complexity, there are other measures that can be important for evaluating algorithms, including:
#
# - **I/O Complexity**: Measures the number of input/output operations an algorithm performs, which can be significant in database and file processing.
# - **Communication Complexity**: Relevant in distributed systems, it measures the amount of communication required between different parts of a system.
# - **Parallel Complexity**: Measures how well an algorithm can be parallelized and how the performance scales with the number of processors.
# - **Amortized Complexity**: Analyzes the average time per operation over a worst-case sequence of operations, useful for data structures that have occasional expensive operations.
#
# These measures provide a more comprehensive understanding of an algorithm's efficiency and suitability for specific applications.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

# %%
# chat_prompt = ChatPromptTemplate.from_messages([
#     ("system", "You are a helpful assistant."),
#     ("human", "What's the capital of France?"),
#     ("ai", "The capital of France is Paris."),
#     ("human", "{input}"),
# ])

# chat_prompt = (
#     SystemMessage(content="You are a helpful assistant.")+
#     HumanMessage(content="What's the capital of France?") +
#     AIMessage(content="The capital of France is Paris.")+
#     HumanMessage(content="{input}")
# )

chat_prompt = (
    SystemMessage(content="You are a helpful assistant.")+
    HumanMessage(content="What's the capital of France?") +
    AIMessage(content="The capital of France is Paris.")+
    "{input}"
)
# chat_prompt.format(input="america?")

gpt =ChatOpenAI( model="gpt-4o-mini", temperature=0)
rst = gpt.invoke( chat_prompt.format(input="america?") )
print( rst.content )
# Out:
# The capital of the United States is Washington, D.C.

# %% [markdown]
# ## FewShotPromptTemplate

# %%
import langchain_core.prompts as pt
print(dir(pt))
# Out:
# ['AIMessagePromptTemplate', 'BaseChatPromptTemplate', 'BasePromptTemplate', 'ChatMessagePromptTemplate', 'ChatPromptTemplate', 'DictPromptTemplate', 'FewShotChatMessagePromptTemplate', 'FewShotPromptTemplate', 'FewShotPromptWithTemplates', 'HumanMessagePromptTemplate', 'MessagesPlaceholder', 'PromptTemplate', 'StringPromptTemplate', 'SystemMessagePromptTemplate', 'aformat_document', 'check_valid_template', 'format_document', 'get_template_variables', 'jinja2_formatter', 'load_prompt', 'validate_jinja2']

# %%
from langchain_core.prompts import FewShotPromptTemplate

# %%
exmaples = [{"input": "Hello","output":"안녕하세요"},
            {"input": "Goodbye","output":"안녕히 가세요"}]

exmaple_promt = PromptTemplate(input_variables=["input", "output"],
                               template="Input: {input}\nOutput: {output}")

few_shot_prompt = FewShotPromptTemplate(
    examples=exmaples,
    example_prompt=exmaple_promt,
    suffix="Input: {input}\nOutput:",
    input_variables=["input"],)

fprompt = few_shot_prompt.format(input="Good night")
print( fprompt)
# Out:
# Input: Hello
# Output: 안녕하세요
#
# Input: Goodbye
# Output: 안녕히 가세요
#
# Input: Good night
# Output:

# %%
gpt = ChatOpenAI( model="gpt-4o-mini", temperature=0)
rst = gpt.invoke( fprompt )
print( rst.content )
# Out:
# 안녕히 주무세요
