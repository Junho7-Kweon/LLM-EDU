# %%
from openai import OpenAI


OPENAI_API_KEY='여기에_본인의_OPENAI_API_키'

client = OpenAI(api_key=OPENAI_API_KEY)
print(client.api_key)
# Out:
# 여기에_본인의_OPENAI_API_키

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(
    api_key=api_key
)

print(client.api_key)
# Out:
#   Cell In[4], line 8
#     api_key=api_key
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(".env", override=True)

if not os.getenv("OPENAI_API_KEY"):
    raise RuntimeError("OPENAI_API_KEY를 불러오지 못했습니다.")

client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "hello world"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# Hello! How can I assist you today?

# %%
# %pip install -U python-dotenv openai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\sk-encore\llm-workspace\.venv\Scripts\python.exe: No module named pip

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI( api_key=api_key
)

print(client.api_key)
# Out:
# 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

# %%
# GPT에게 첫 번째 질문을 보냅니다
response = client.chat.completions.create(
    model="gpt-4o-mini",          # 사용할 모델
    messages=[
        {"role": "system", "content": "당신은 친절한 AI 어시스턴트입니다."},
        {"role": "user",   "content": "파인튜닝이 무엇인지 한 문장으로 설명해 주세요."}
    ],
    temperature=0.7,   # 창의성 수준 (0~2, 높을수록 다양한 답변)
    max_tokens=512,    # 최대 응답 길이
    stream=False             # 스트리밍 모드 활성화
)

# GPT의 답변만 뽑아서 출력
#stream=false일때 사용
print(response.choices[0].message.content)
# Out:
# 파인튜닝이란, 이미 학습된 모델을 특정 작업이나 데이터셋에 맞게 추가적으로 학습시켜 성능을 개선하는 과정입니다.

# %%
# ① system 없이 질문
response_no_sys = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "계약 해지 통보는 언제 해야 하나요?"}
    ],
    temperature=0.3,
    max_tokens=200,
)

# ② system 있이 질문
response_with_sys = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "당신은 대한민국 법률 전문가입니다. 관련 법조항을 인용하여 3문장 이내로 답변하세요."},
        {"role": "user",   "content": "계약 해지 통보는 언제 해야 하나요?"}
    ],
    temperature=0.3,
    max_tokens=200,
)

print("─── system 없음 ───")
print(response_no_sys.choices[0].message.content)

print("\n─── system 있음 ───")
print(response_with_sys.choices[0].message.content)
# Out:
# ─── system 없음 ───
# 계약 해지 통보는 계약서에 명시된 해지 조건이나 통보 기간에 따라 달라질 수 있습니다. 일반적으로 다음과 같은 경우에 해지 통보를 해야 합니다:
#
# 1. **계약서의 규정**: 계약서에 해지 통보를 해야 하는 시점이나 기간이 명시되어 있는 경우, 그에 따라 통보해야 합니다.
#
# 2. **법적 요건**: 특정 계약 유형(예: 임대차 계약, 근로 계약 등)에는 법적으로 정해진 해지 통보 기간이 있을 수 있습니다. 이를 준수해야 합니다.
#
# 3. **상대방의 의무 불이행**: 계약 상대방이 계약의 의무를 이행하지 않는 경우, 해지 통보를 할 수 있습니다. 이 경우에도 계약서에 명시된 절차를 따라야 합니다.
#
# 4. **상황 변화**: 계약을 지속하기 어려운 상황이
#
# ─── system 있음 ───
# 계약 해지 통보는 민법 제자 548조에 따라 계약의 해지 사유가 발생한 경우 즉시 통보해야 합니다. 또한, 계약서에 별도로 정해진 해지 통보 기간이 있을 경우 해당 기간을 준수해야 합니다. 따라서 계약의 성격과 조건에 따라 해지 통보 시점을 결정해야 합니다.

# %%
# 앞에서 받은 response 를 해부해봅니다
print("📝 답변 내용:")
print(response.choices[0].message.content)   # 실제 답변

print("\n🏁 종료 이유:", response.choices[0].finish_reason)  # stop / length

print("\n📊 토큰 사용량:")
print("   입력 토큰:", response.usage.prompt_tokens)
print("   출력 토큰:", response.usage.completion_tokens)
print("   전체 토큰:", response.usage.total_tokens)
# Out:
# 📝 답변 내용:
# 파인튜닝은 사전 학습된 모델을 특정 작업이나 데이터셋에 맞게 추가 학습하여 성능을 개선하는 과정입니다.
#
# 🏁 종료 이유: stop
#
# 📊 토큰 사용량:
#    입력 토큰: 40
#    출력 토큰: 33
#    전체 토큰: 73

# %%
# 🧪 실험: max_tokens 를 너무 작게 하면 어떻게 될까?
response_short = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "대한민국 헌법의 기본 원리를 상세히 설명해 주세요."}
    ],
    max_tokens=20,   # 의도적으로 아주 짧게 설정
)

print("답변:", response_short.choices[0].message.content)
print("종료 이유:", response_short.choices[0].finish_reason)  # → "length"
print("→ 문장이 중간에 잘렸습니다! max_tokens를 늘려야 합니다.")
# Out:
# 답변: 대한민국 헌법의 기본 원리는 여러 가지 중요한 요소로 구성되어 있습니다. 이러한 원
# 종료 이유: length
# → 문장이 중간에 잘렸습니다! max_tokens를 늘려야 합니다.

# %%
# 방금 호출한 API의 비용을 직접 계산해봅니다
INPUT_PRICE  = 0.15   # 입력: $0.15 / 100만 토큰
OUTPUT_PRICE = 0.60   # 출력: $0.60 / 100만 토큰

# 사용한 토큰 수 가져오기
input_tokens  = response.usage.prompt_tokens
output_tokens = response.usage.completion_tokens

# 비용 계산 (달러)
total_cost = (input_tokens * INPUT_PRICE + output_tokens * OUTPUT_PRICE) / 1_000_000

print(f"입력: {input_tokens}토큰 / 출력: {output_tokens}토큰")
print(f"이번 호출 비용: ${total_cost:.6f}  (약 {total_cost * 1400:.4f}원)")
print(f"1,000번 호출하면: 약 {total_cost * 1000 * 1400:.0f}원")
# Out:
# 입력: 40토큰 / 출력: 33토큰
# 이번 호출 비용: $0.000026  (약 0.0361원)
# 1,000번 호출하면: 약 36원

# %%
# 호출할 때마다 토큰과 비용을 쌓아주는 추적기
class TokenTracker:
    def __init__(self):
        self.total_input  = 0
        self.total_output = 0
        self.call_count   = 0

    def add(self, response):               # API 응답을 넣으면 자동으로 집계
        self.total_input  += response.usage.prompt_tokens
        self.total_output += response.usage.completion_tokens
        self.call_count   += 1

    def report(self):                      # 지금까지 쓴 비용 출력
        cost = (self.total_input * 0.15 + self.total_output * 0.60) / 1_000_000
        print(f"총 {self.call_count}회 호출 | 입력 {self.total_input} + 출력 {self.total_output} 토큰")
        print(f"누적 비용: ${cost:.4f} (약 {cost * 1400:.0f}원)")

# 사용법 예시
tracker = TokenTracker()
tracker.add(response)     # 아까 받은 응답 등록
tracker.report()          # 지금까지 쓴 비용 출력
# Out:
# 총 1회 호출 | 입력 40 + 출력 33 토큰
# 누적 비용: $0.0000 (약 0원)
